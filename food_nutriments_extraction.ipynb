# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')
print(df.shape)
print(df.columns)
df.head()
# Out:
# (8790, 53)
# Index(['NDB_No', 'Short_Description', 'Water_In_Grams',
#        'Energy_In_Kilogram_Calorie', 'Protein_In_Grams', 'Lipid_Tot_In_Grams',
#        'Ash_In_Grams', 'Carbohydrate_In_Grams', 'Fiber_TD_In_Grams',
#        'Sugar_Tot_In_Grams', 'Calcium_In_Miligrams', 'Iron_In_Miligrams',
#        'Magnesium_In_Miligrams', 'Phosphorus_In_Miligrams',
#        'Potassium_In_Miligrams', 'Sodium_In_Miligrams', 'Zinc_In_Miligrams',
#        'Copper_In_Miligrams', 'Manganese_In_Miligrams',
#        'Selenium_In_Micrograms', 'Vit_C_In_Miligrams', 'Thiamin_In_Miligrams',
#        'Riboflavin_In_Miligrams', 'Niacin_In_Miligrams',
#        'Panto_Acid_In_Miligrams', 'Vit_B6_In_Miligrams',
#        'Folate_Tot_In_Micrograms', 'Folic_Acid_In_Micrograms',
#        'Food_Folate_In_Micrograms', 'Folate_DFE_In_Micrograms',
#        'Choline_Tot_In_Miligrams', 'Vit_B12_In_Micrograms',
#        'Vit_A_In_International_Unit', 'Vit_A_In_Retinol_Activity_Equivalents',
# ...

# %%
df[['Short_Description','Energy_In_Kilogram_Calorie','Protein_In_Grams','Carbohydrate_In_Grams','Lipid_Tot_In_Grams']]
# Out:
#                Short_Description  Energy_In_Kilogram_Calorie  \
# 0               BUTTER,WITH SALT                         717
# 1         BUTTER,WHIPPED,W/ SALT                         718
# 2           BUTTER OIL,ANHYDROUS                         876
# 3                    CHEESE,BLUE                         353
# 4                   CHEESE,BRICK                         371
# ...                          ...                         ...
# 8785             MACKEREL,SALTED                         305
# 8786  SCALLOP,(BAY&SEA),CKD,STMD                         111
# 8787                  SYRUP,CANE                         269
# 8788                   SNAIL,RAW                          90
# 8789            TURTLE,GREEN,RAW                          89
#
#       Protein_In_Grams  Carbohydrate_In_Grams  Lipid_Tot_In_Grams
# 0                 0.85                   0.06               81.11
# 1                 0.49                   2.87               78.30
# ...

# %%
df = pd.read_csv('nutrition.csv')
print(df.shape)
print(df.columns)
df.head()
# Out:
# (8789, 77)
# Index(['Unnamed: 0', 'name', 'serving_size', 'calories', 'total_fat',
#        'saturated_fat', 'cholesterol', 'sodium', 'choline', 'folate',
#        'folic_acid', 'niacin', 'pantothenic_acid', 'riboflavin', 'thiamin',
#        'vitamin_a', 'vitamin_a_rae', 'carotene_alpha', 'carotene_beta',
#        'cryptoxanthin_beta', 'lutein_zeaxanthin', 'lucopene', 'vitamin_b12',
#        'vitamin_b6', 'vitamin_c', 'vitamin_d', 'vitamin_e', 'tocopherol_alpha',
#        'vitamin_k', 'calcium', 'copper', 'irom', 'magnesium', 'manganese',
#        'phosphorous', 'potassium', 'selenium', 'zink', 'protein', 'alanine',
#        'arginine', 'aspartic_acid', 'cystine', 'glutamic_acid', 'glycine',
#        'histidine', 'hydroxyproline', 'isoleucine', 'leucine', 'lysine',
#        'methionine', 'phenylalanine', 'proline', 'serine', 'threonine',
#        'tryptophan', 'tyrosine', 'valine', 'carbohydrate', 'fiber', 'sugars',
# ...

# %%
df[['name','serving_size','calories','protein','carbohydrate','total_fat']].head(50)
# Out:
#                       name serving_size  calories  protein carbohydrate  \
# 0               Cornstarch        100 g       381   0.26 g      91.27 g
# 1             Nuts, pecans        100 g       691   9.17 g      13.86 g
# 2            Eggplant, raw        100 g        25   0.98 g       5.88 g
# 3           Teff, uncooked        100 g       367  13.30 g      73.13 g
# 4          Sherbet, orange        100 g       144   1.10 g      30.40 g
# 5         Cauliflower, raw        100 g        25   1.92 g       4.97 g
# 6         Taro leaves, raw        100 g        42   4.98 g       6.70 g
# 7        Lamb, raw, ground        100 g       282  16.56 g       0.00 g
# 8        Cheese, camembert        100 g       300  19.80 g       0.46 g
# 9       Vegetarian fillets        100 g       290  23.00 g       9.00 g
# 10     PACE, Picante Sauce        100 g        25   0.00 g       6.25 g
# 11     Goji berries, dried        100 g       349  14.26 g      77.06 g
# ...
